# %% [markdown]
# # Pandapower Grid from Library
#
# This notebook demonstrates how to create and analyze power grids using **pandapower** — including loading built-in network examples from the pandapower networks library.

# %% [markdown]
# ## 1. Install & Import

# %%
from pandapower.networks import create_cigre_network_mv

net = create_cigre_network_mv(with_der="all")
